# %% [markdown]
# <a href="https://colab.research.google.com/github/hariprasanth-22/NLP-Tasks-with-Hugging-Face-Transformers/blob/main/NLP_with_Transformers.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install transformers

# %%
from transformers import pipeline
classifier=pipeline("sentiment-analysis")
# classifier=("This is the best day in my life") # This line was overwriting the pipeline
# Out:
# No model was supplied, defaulted to distilbert/distilbert-base-uncased-finetuned-sst-2-english and revision 714eb0f (https://huggingface.co/distilbert/distilbert-base-uncased-finetuned-sst-2-english).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# Device set to use cuda:0

# %%
classifier(
    ['I have been waiting for a Huggingface course in my whole life','Today I am so Tired']
)
# Out:
# [{'label': 'POSITIVE', 'score': 0.753975510597229},
#  {'label': 'NEGATIVE', 'score': 0.9997604489326477}]

# %%
from transformers import pipeline
classifier=pipeline("zero-shot-classification")
classifier("I am working on my project",
           candidate_labels=["eductaion","politics","bussiness"])
# Out:
# No model was supplied, defaulted to facebook/bart-large-mnli and revision d7645e1 (https://huggingface.co/facebook/bart-large-mnli).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# config.json: 0.00B [00:00, ?B/s]
# model.safetensors:   0%|          | 0.00/1.63G [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# Device set to use cuda:0
# {'sequence': 'I am working on my project',
#  'labels': ['eductaion', 'bussiness', 'politics'],
#  'scores': [0.719200849533081, 0.2283836156129837, 0.052415523678064346]}

# %%
generator=pipeline("text-generation")
generator("Today climate is good")
# Out:
# No model was supplied, defaulted to openai-community/gpt2 and revision 607a30d (https://huggingface.co/openai-community/gpt2).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# Device set to use cuda:0
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# ...

# %%
from huggingface_hub import login
login(new_session=False)

# %%
# Use a pipeline as a high-level helper
from transformers import pipeline

pipe = pipeline("text-generation", model="apple/sage-ft-mixtral-8x7b")
messages = [
    {"role": "user", "content": "Who are you?"},
]
pipe(messages)
# Out:
# config.json:   0%|          | 0.00/831 [00:00<?, ?B/s]
# model.safetensors.index.json: 0.00B [00:00, ?B/s]
# Fetching 48 files:   0%|          | 0/48 [00:00<?, ?it/s]
# model-00001-of-00048.safetensors:   0%|          | 0.00/1.99G [00:00<?, ?B/s]
# model-00002-of-00048.safetensors:   0%|          | 0.00/1.96G [00:00<?, ?B/s]
# model-00005-of-00048.safetensors:   0%|          | 0.00/1.96G [00:00<?, ?B/s]
# model-00004-of-00048.safetensors:   0%|          | 0.00/1.96G [00:00<?, ?B/s]
# model-00006-of-00048.safetensors:   0%|          | 0.00/2.00G [00:00<?, ?B/s]
# model-00003-of-00048.safetensors:   0%|          | 0.00/2.00G [00:00<?, ?B/s]
# model-00008-of-00048.safetensors:   0%|          | 0.00/1.96G [00:00<?, ?B/s]
# model-00007-of-00048.safetensors:   0%|          | 0.00/1.96G [00:00<?, ?B/s]
# model-00009-of-00048.safetensors:   0%|          | 0.00/1.96G [00:00<?, ?B/s]
# model-00010-of-00048.safetensors:   0%|          | 0.00/2.00G [00:00<?, ?B/s]
# ...

# %%
# Load model directly
from transformers import AutoTokenizer, AutoModelForCausalLM

tokenizer = AutoTokenizer.from_pretrained("apple/sage-ft-mixtral-8x7b")
model = AutoModelForCausalLM.from_pretrained("apple/sage-ft-mixtral-8x7b")

# %%
# Use a pipeline as a high-level helper
from transformers import pipeline

pipe = pipeline("text-generation", model="KurmaAI/AQUA-1B")
messages = [
    {"role": "user", "content": "Who are you?"},
]
pipe(messages)
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/894 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/2.00G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/210 [00:00<?, ?B/s]
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# tokenizer.model:   0%|          | 0.00/4.69M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/33.4M [00:00<?, ?B/s]
# added_tokens.json:   0%|          | 0.00/35.0 [00:00<?, ?B/s]
# ...

# %%
# Load model directly
from transformers import AutoTokenizer, AutoModelForCausalLM

tokenizer = AutoTokenizer.from_pretrained("KurmaAI/AQUA-1B")
model = AutoModelForCausalLM.from_pretrained("KurmaAI/AQUA-1B")

# %%
from transformers import pipeline
unmasker=pipeline("fill-mask")
unmasker("This is a great <mask>!")
# Out:
# No model was supplied, defaulted to distilbert/distilroberta-base and revision fb53ab8 (https://huggingface.co/distilbert/distilroberta-base).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# Some weights of the model checkpoint at distilbert/distilroberta-base were not used when initializing RobertaForMaskedLM: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# - This IS expected if you are initializing RobertaForMaskedLM from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaForMaskedLM from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Device set to use cpu
# [{'score': 0.041885826736688614,
#   'token': 4085,
# ...

# %%
ner=pipeline ("ner",grouped_entities=True)
ner("My name is hari and I am work at hugging face in Brookly.")
# Out:
# No model was supplied, defaulted to dbmdz/bert-large-cased-finetuned-conll03-english and revision 4c53496 (https://huggingface.co/dbmdz/bert-large-cased-finetuned-conll03-english).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# config.json:   0%|          | 0.00/998 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/1.33G [00:00<?, ?B/s]
# Some weights of the model checkpoint at dbmdz/bert-large-cased-finetuned-conll03-english were not used when initializing BertForTokenClassification: ['bert.pooler.dense.bias', 'bert.pooler.dense.weight']
# - This IS expected if you are initializing BertForTokenClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# ...

# %%
from transformers import pipeline
question_answerer=pipeline("question-answering")
question_answerer(
    question="How many images are there in the Fashion MNIST dataset?",
    context="The Fashion MNIST dataset is a popular benchmark dataset used in machine learning and computer vision. It contains 70,000 grayscale images of fashion items, divided into 10 categories such as T-shirts, trousers, pullovers, dresses, and sneakers. Each image is 28x28 pixels in size. The dataset is split into 60,000 training images and 10,000 test images. It was created by researchers at Zalando, a German online fashion retailer, as a more challenging alternative to the MNIST handwritten digits dataset."
)
# Out:
# No model was supplied, defaulted to distilbert/distilbert-base-cased-distilled-squad and revision 564e9b5 (https://huggingface.co/distilbert/distilbert-base-cased-distilled-squad).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# Device set to use cpu
# {'score': 0.8145509958267212, 'start': 115, 'end': 121, 'answer': '70,000'}

# %%
summarizer=pipeline("summarization")
summarizer(
    """The Fashion MNIST dataset is a widely recognized benchmark used in the fields of machine learning and computer vision, particularly for image classification tasks. It comprises a total of 70,000 grayscale images of various fashion products that are divided into 10 distinct categories: T-shirt/top, trouser, pullover, dress, coat, sandal, shirt, sneaker, bag, and ankle boot. Each image is in grayscale and has a resolution of 28 by 28 pixels, resulting in a total of 784 pixels per image. The dataset is split into 60,000 training images and 10,000 testing images, enabling researchers and developers to train and evaluate models effectively. Fashion MNIST was introduced by Zalando, a German online fashion retail company, as a more modern and practical alternative to the original MNIST dataset, which contained images of handwritten digits. While MNIST was easy to solve using traditional methods, Fashion MNIST presents a more challenging task due to the similarity between certain classes, such as shirts and T-shirts or coats and pullovers. The dataset is formatted to match the structure of MNIST, so it can be easily used as a drop-in replacement. It is particularly popular among beginners in deep learning because of its manageable size and simplicity, yet it provides enough complexity to demonstrate the strengths of advanced models like Convolutional Neural Networks (CNNs). In addition to CNNs, the dataset is also used for experimenting with other deep learning architectures such as fully connected neural networks, recurrent neural networks (RNNs), and autoencoders. Due to its consistent structure, open access, and real-world relevance, Fashion MNIST has become a foundational tool for prototyping models, testing ideas, and learning the basics of image classification and neural network training.
"""
)
# Out:
# No model was supplied, defaulted to sshleifer/distilbart-cnn-12-6 and revision a4f8f3e (https://huggingface.co/sshleifer/distilbart-cnn-12-6).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# config.json: 0.00B [00:00, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/1.22G [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/1.22G [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# Device set to use cpu
# [{'summary_text': ' The Fashion MNIST dataset is a widely recognized benchmark used in the fields of machine learning and computer vision . It comprises a total of 70,000 grayscale images of various fashion products that are divided into 10 distinct categories . The dataset is split into 60,000 training images and 10,000 testing images, enabling researchers and developers to train and evaluate models effectively .'}]

# %%
from transformers import AutoTokenizer,AutoModelForSequenceClassification
import torch

# %%
tokenizer=AutoTokenizer.from_pretrained("distilbert-base-uncased-finetuned-sst-2-english")
model=AutoModelForSequenceClassification.from_pretrained("distilbert-base-uncased-finetuned-sst-2-english")
# Out:
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/629 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/268M [00:00<?, ?B/s]

# %%
sentence="I Love this!"

# %%
inputs=tokenizer(sentence,return_tensors="pt")

# %%
outputs=model(**inputs)

# %%
probabilities=torch.softmax(outputs.logits,dim=1)

# %%
probabilities
# Out:
# tensor([[1.2351e-04, 9.9988e-01]], grad_fn=<SoftmaxBackward0>)

# %%
label_id=torch.argmax(probabilities).item()
label=model.config.id2label[label_id]

# %%
label_id
# Out:
# 1
